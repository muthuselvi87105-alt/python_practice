# %%
l=[59,1,89,30,2,5]
i=0

current_min=l[0]
current_max=l[0]

while i < len(l):
    if l[i] < current_min:
        current_min =l[i]
    if l[i] > current_max:
        current_max =l[i]
    i=i+1
print("Minimun:",current_min) 
print("Maximum:",current_max)
# Out:
# Minimun: 1
# Maximum: 89

# %%
l=[59,1,89,30,2,5]
i=0

second_smallest=l[0]
second_largest=l[0]

while i < len(l):
    if l[i] < second_smallest:
        second_smallest = l[i]
    if l[i] > second_largest:
        second_largest =l[i]
    i=i+1
print("second smallest",second_smallest)
print("second largest",second_largest)
# Out:
# second smallest 1
# second largest 89

# %%
l = [59, 1, 89, 30, 2, 5]
i = 0
smallest = l[0]
largest = l[0]

while i < len(l):
    if l[i] < smallest:
        smallest = l[i]
    if l[i] > largest:
        largest = l[i]
    i += 1

second_smallest = float('inf')  
second_largest = float('-inf')  

i = 0
while i < len(l):
    if l[i] != smallest and l[i] < second_smallest:
        second_smallest = l[i]
    if l[i] != largest and l[i] > second_largest:
        second_largest = l[i]
    i += 1

print("Second smallest:", second_smallest)
print("Second largest:", second_largest)
# Out:
# Second smallest: 2
# Second largest: 59
