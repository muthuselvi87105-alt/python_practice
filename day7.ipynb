# %%
list1=["Hi",24,67,75.9,3j+5,"apple",True,78,"hello"]
list2=[33,56,78,90,26,42]
list1.insert(2,"python")
list1.remove(True)
list1.pop(4)
list2.extend(list1)
print(list2)
# Out:
# [33, 56, 78, 90, 26, 42, 'Hi', 24, 'python', 67, (5+3j), 'apple', 78, 'hello']

# %%
l=[1,2,3,4,5,6,7,8]
l[2:4]=["hi"]
print(l)
# Out:
# [1, 2, 'h', 'i', 5, 6, 7, 8]

# %%
L1 = ["apple", "banana", "cherry"]
L2 = [1, 2, 3]

for i in range(len(L1)):
    print(L1[i] + " " + str(L2[i]))

# %%
list=[1,2,34,67,89,34]
list.sort()
print(list)
# Out:
# [1, 2, 34, 34, 67, 89]

# %%
mylist= (1,3,8,7,5,4,6,8,5)

x=mylist.index(5)

print(x)
# Out:
# 4

# %%
myset = { "banana","apple","hji",9,78,"hello"}
print(myset)
x = myset.pop()

print(x)
# Out:
# {'apple', 'hello', 78, 9, 'hji', 'banana'}
# apple

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena",3}
set4 = {"apple", "bananas", "cherry"}

myset = set1.union(set2, set3, set4)
print(myset)
# Out:
# {'John', 1, 2, 3, 'c', 'b', 'Elena', 'apple', 'bananas', 'cherry', 'a'}

# %%
set1 = {"a", "b", "c"}
set2 = {1, 2, 3}
set3 = {"John", "Elena"}
set4 = {"apple", "bananas", "cherry"}

myset = set1 | set2 | set3 |set4
print(myset)
# Out:
# {'John', 1, 2, 3, 'c', 'b', 'Elena', 'apple', 'bananas', 'cherry', 'a'}

# %%
set1 = {"apple", 1,  "banana", 0, "cherry"}
set2 = {False, "google", 1, "apple", 2, True}

set3 = set1.intersection(set2)

print(set3)
# Out:
# {False, 1, 'apple'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set2 - set1
print(set3)
# Out:
# {'microsoft', 'google'}

# %%
set1 = {"apple", "banana", "cherry"}
set2 = {"google", "microsoft", "apple"}

set3 = set1 ^ set2
print(set3)
# Out:
# {'microsoft', 'google', 'cherry', 'banana'}
