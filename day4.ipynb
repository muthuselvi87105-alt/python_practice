# %%
a=5
b=10
c=a+b
print(c)
# Out:
# 15

# %%
a=5
b=10
c=a-b
print(c)
# Out:
# -5

# %%
a=5
b=10
c=a*b
print(c)
# Out:
# 50

# %%
a=5
b=10
c=a/b
print(c)
# Out:
# 0.5

# %%
a=5
b=10
c=a%b
print(c)
# Out:
# 5

# %%
a=5
b=10
c=a%b
print(c)

# %%
a=5
b=10
c=a**b
print(c)
# Out:
# 9765625

# %%
a=5
b=10
c=a//b
print(c)
# Out:
# 0

# %%
a=5
b=15
c=a<b
print(c)
# Out:
# True

# %%
a=5
b=15
c=a>b
print(c)
# Out:
# False

# %%
a=5
b=15
c=a>=b
print(c)
# Out:
# False

# %%
a=5
b=15
c=a<=b
print(c)
# Out:
# True

# %%
a=5
b=15
c=(a==b)
print(c)
# Out:
# False

# %%
a=5
b=15
c=(a+b)
print(c)
# Out:
# 20

# %%
c=c+a
print(c)
# Out:
# 25

# %%
c=c-a
print(c)
# Out:
# 20

# %%
c=c*a
print(c)
# Out:
# 100

# %%
c=c/a
print(c)
# Out:
# 20.0

# %%
c=c**a
print(c)
# Out:
# 3200000.0

# %%
c=c//a
print(c)
# Out:
# 640000.0

# %%
c=c%a
print(c)
# Out:
# 0.0
