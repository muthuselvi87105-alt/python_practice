# %%
L=[1,2,3,4,53,2,1,25]
unique_list=[]
for i in L:
    if i not in unique_list:
        unique_list.append(i)
print(unique_list)

# %%
L=[1,2,3,4,3,2,1,25]
D={}
for i in L:
    if i in D:
        D[i]+=1
    else:
        D[i]=1
print(D)
