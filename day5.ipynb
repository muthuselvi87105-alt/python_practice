# %%
skill=input("Enter a skill")
Experience=input("Enter a Experience")
Location=input("Enter a Location")

if skill=="python" and Experience=="1year" and Location=="chennai":
    print("Eligible for infosys")
elif skill=="python" and Experience=="Fresher" and Location=="coimbatore":
    print("Eligible for wipro")
elif skill=="java" and Experience=="Fresher" and Location=="chennai":
    print("Eligible for tcs")
elif skill=="java" and Experience=="1year" and Location=="bangalore":
    print("Eligible for cognizant")
else:
    print("Not matching")
