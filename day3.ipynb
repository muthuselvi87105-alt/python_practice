# %%
txt="Hello My name is PETER"
x=txt.swapcase
print(x)
# Out:
# <built-in method swapcase of str object at 0x000001F2AC173930>

# %%
txt="Hello,welcome to my world."
x=txt.endswith(".")
print(x)
# Out:
# True

# %%
txt="Demo"
x=str. isidentififer()
print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 2
#       1 txt="Demo"
# ----> 2 x=str. isidentififer()
#       3 print(x)
#
# AttributeError: type object 'str' has no attribute 'isidentififer'

# %%
txt="58000"
x=txt.isdigit
print(x)
# Out:
# <built-in method isdigit of str object at 0x000001F2AC0BAEB0>

# %%
txt="Hello sam!"
mytable=str.maketrans("s","r")
print(txt.translate(mytable))
# Out:
# Hello ram!
